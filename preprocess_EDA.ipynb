# %%
#!pip install modin[all]

# %%
#import modin.pandas as pd
import pandas as pd

tp = pd.read_csv("/content/drive/MyDrive/kurly_hackathon/data/2019-Nov.csv", iterator=True, chunksize=1000)
df = pd.concat(tp, ignore_index=True)
